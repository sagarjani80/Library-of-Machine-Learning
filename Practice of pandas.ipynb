# %%
import pandas as pd

# %%
name = pd.Series(["sagar","vrutik","chirag","heet","harsh"])

# %%
surname = pd.Series(["jani","prajapati","vyas","patel","kalsariya"])

# %%
age = pd.Series([20,19,19,20,20])

# %%
name
# Out:
# 0     sagar
# 1    vrutik
# 2    chirag
# 3      heet
# 4     harsh
# dtype: object

# %%
surname
# Out:
# 0         jani
# 1    prajapati
# 2         vyas
# 3        patel
# 4    kalsariya
# dtype: object

# %%
age
# Out:
# 0    20
# 1    19
# 2    19
# 3    20
# 4    20
# dtype: int64

# %%
dataframe = pd.DataFrame({"name":name,"surname":surname,"Age":age})

# %%
dataframe
# Out:
#      name    surname  Age
# 0   sagar       jani   20
# 1  vrutik  prajapati   19
# 2  chirag       vyas   19
# 3    heet      patel   20
# 4   harsh  kalsariya   20

# %%
df = pd.read_csv("Bs.csv")

# %%
df
# Out:
#    DEMOGRAPHIC DETAILS  Unnamed: 1      Unnamed: 2            Unnamed: 3  \
# 0                 SR NO        AGE  MONTHLY INCOME  NO OF FAMILY MEMBERS
# 1                     1         22           10200                     4
# 2                     2         28           18700                     5
# 3                     3         30           21500                     3
# 4                     4         29           22700                     6
# 5                     5         35           17000                     7
# 6                     6         38           15000                     6
# 7                     7         32           25600                     8
# 8                     8         21           12500                     5
# 9                     9         41           30000                     6
# 10                   10         39           16800                     7
# 11                   11         44           24600                     2
# ...

# %%
df.to_csv("sample.csv" , index = False)

# %%
df
# Out:
#    DEMOGRAPHIC DETAILS  Unnamed: 1      Unnamed: 2            Unnamed: 3  \
# 0                 SR NO        AGE  MONTHLY INCOME  NO OF FAMILY MEMBERS
# 1                     1         22           10200                     4
# 2                     2         28           18700                     5
# 3                     3         30           21500                     3
# 4                     4         29           22700                     6
# 5                     5         35           17000                     7
# 6                     6         38           15000                     6
# 7                     7         32           25600                     8
# 8                     8         21           12500                     5
# 9                     9         41           30000                     6
# 10                   10         39           16800                     7
# 11                   11         44           24600                     2
# ...

# %%
export = pd.read_csv("sample.csv")

# %%
export
# Out:
#    DEMOGRAPHIC DETAILS  Unnamed: 1      Unnamed: 2            Unnamed: 3  \
# 0                 SR NO        AGE  MONTHLY INCOME  NO OF FAMILY MEMBERS
# 1                     1         22           10200                     4
# 2                     2         28           18700                     5
# 3                     3         30           21500                     3
# 4                     4         29           22700                     6
# 5                     5         35           17000                     7
# 6                     6         38           15000                     6
# 7                     7         32           25600                     8
# 8                     8         21           12500                     5
# 9                     9         41           30000                     6
# 10                   10         39           16800                     7
# 11                   11         44           24600                     2
# ...

# %%
df
# Out:
#    DEMOGRAPHIC DETAILS  Unnamed: 1      Unnamed: 2            Unnamed: 3  \
# 0                 SR NO        AGE  MONTHLY INCOME  NO OF FAMILY MEMBERS
# 1                     1         22           10200                     4
# 2                     2         28           18700                     5
# 3                     3         30           21500                     3
# 4                     4         29           22700                     6
# 5                     5         35           17000                     7
# 6                     6         38           15000                     6
# 7                     7         32           25600                     8
# 8                     8         21           12500                     5
# 9                     9         41           30000                     6
# 10                   10         39           16800                     7
# 11                   11         44           24600                     2
# ...

# %%
df.dtypes
# Out:
# DEMOGRAPHIC DETAILS     object
# Unnamed: 1              object
# Unnamed: 2              object
# Unnamed: 3              object
# Unnamed: 4              object
# dtype: object

# %%
df.columns
# Out:
# Index(['DEMOGRAPHIC DETAILS ', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=52, step=1)

# %%
df.describe()
# Out:
#        DEMOGRAPHIC DETAILS  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# count                    51         51         51         51         51
# unique                   51         36         44         12         36
# top                   SR NO         36      32500          6         61
# freq                      1          3          2         11          3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DEMOGRAPHIC DETAILS   51 non-null     object
#  1   Unnamed: 1            51 non-null     object
#  2   Unnamed: 2            51 non-null     object
#  3   Unnamed: 3            51 non-null     object
#  4   Unnamed: 4            51 non-null     object
# dtypes: object(5)
# memory usage: 2.2+ KB

# %%
df.sum()
# Out:
# C:\Users\AMITJA~1\AppData\Local\Temp/ipykernel_7036/1703867807.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.sum()
# Series([], dtype: float64)

# %%
len(df)
# Out:
# 52

# %%
df
# Out:
#    DEMOGRAPHIC DETAILS  Unnamed: 1      Unnamed: 2            Unnamed: 3  \
# 0                 SR NO        AGE  MONTHLY INCOME  NO OF FAMILY MEMBERS
# 1                     1         22           10200                     4
# 2                     2         28           18700                     5
# 3                     3         30           21500                     3
# 4                     4         29           22700                     6
# 5                     5         35           17000                     7
# 6                     6         38           15000                     6
# 7                     7         32           25600                     8
# 8                     8         21           12500                     5
# 9                     9         41           30000                     6
# 10                   10         39           16800                     7
# 11                   11         44           24600                     2
# ...

# %%
sample = pd.read_csv("sample.csv")

# %%
sample
# Out:
#    DEMOGRAPHIC DETAILS  Unnamed: 1      Unnamed: 2            Unnamed: 3  \
# 0                 SR NO        AGE  MONTHLY INCOME  NO OF FAMILY MEMBERS
# 1                     1         22           10200                     4
# 2                     2         28           18700                     5
# 3                     3         30           21500                     3
# 4                     4         29           22700                     6
# 5                     5         35           17000                     7
# 6                     6         38           15000                     6
# 7                     7         32           25600                     8
# 8                     8         21           12500                     5
# 9                     9         41           30000                     6
# 10                   10         39           16800                     7
# 11                   11         44           24600                     2
# ...

# %%
sample = pd.read_csv("sample4.csv")

# %%
sample
# Out:
#      Game Number   "Game Length"
# 0              1              30
# 1              2              29
# 2              3              31
# 3              4              16
# 4              5              24
# ..           ...             ...
# 995          996              24
# 996          997              21
# 997          998              47
# 998          999              30
# 999         1000              12
#
# [1000 rows x 2 columns]

# %%
sample.dtypes
# Out:
# Game Number       int64
#  "Game Length"    int64
# dtype: object

# %%
sample.columns
# Out:
# Index(['Game Number', ' "Game Length"'], dtype='object')

# %%
sample.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
sample.describe()
# Out:
#        Game Number   "Game Length"
# count  1000.000000     1000.000000
# mean    500.500000       35.411000
# std     288.819436       23.412608
# min       1.000000        7.000000
# 25%     250.750000       19.000000
# 50%     500.500000       30.000000
# 75%     750.250000       45.000000
# max    1000.000000      197.000000

# %%
sample.sum()
# Out:
# Game Number       500500
#  "Game Length"     35411
# dtype: int64

# %%
sample["Game Number"].sum()
# Out:
# 500500

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Game Number     1000 non-null   int64
#  1    "Game Length"  1000 non-null   int64
# dtypes: int64(2)
# memory usage: 15.8 KB

# %%
sample.mean()
# Out:
# Game Number       500.500
#  "Game Length"     35.411
# dtype: float64

# %%
import pandas as pd
animal = pd.Series(["cat","dog","lion","tiger","birds","monkey"],index = [0,2,4,6,8,10])

# %%
animal
# Out:
# 0        cat
# 2        dog
# 4       lion
# 6      tiger
# 8      birds
# 10    monkey
# dtype: object

# %% [markdown]
# ## .loc and .iloc

# %%
#loc ris referred to the index
animal.loc[2]
# Out:
# 'dog'

# %%
#iloc is referred to the position
animal.iloc[2]
# Out:
# 'lion'

# %%
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[9]
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)        31600
# Doors                    4
# Price            $9,700.00
# Name: 9, dtype: object

# %%
car_sales.iloc[4]
# Out:
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Colour"] == "Blue"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00

# %%
car_sales[car_sales["Price"] <= "$4,500" ]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[$\,\.]','').astype(int)
# Out:
# C:\Users\AMIT JANI\AppData\Local\Temp\ipykernel_5964\3148099194.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[$\,\.]','').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales["Price"] <= 500000]
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4  400000
# 1   Honda    Red          87899      4  500000
# 4  Nissan  White         213095      4  350000
# 5  Toyota  Green          99213      4  450000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
car_sales = pd.read_csv("car-sales.csv")
x = car_sales[car_sales["Colour"] == "White"]
# OneHotEncoder is used to convert culumn data in to numeric form
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
categorical_feature = ["Colour"]
one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot" , one_hot,
                                 categorical_feature)],
                               remainder = "passthrough")
transformer_x = transformer.fit_transform(x)

transformer_x.
# Out:
# array([[1.0, 'Toyota', 150043, 4, '$4,000.00'],
#        [1.0, 'Nissan', 213095, 4, '$3,500.00'],
#        [1.0, 'Toyota', 60000, 4, '$6,250.00'],
#        [1.0, 'Nissan', 31600, 4, '$9,700.00']], dtype=object)

# %%
x
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
import pandas as pd

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
import pandas as pd

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot();

# %%
import pandas as pd

# %%
cs=pd.read_csv("car-sales.csv")

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
##convert in lower case
cs["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
cs.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
cs["Make"].str.upper()
# Out:
# 0    TOYOTA
# 1     HONDA
# 2    TOYOTA
# 3       BMW
# 4    NISSAN
# 5    TOYOTA
# 6     HONDA
# 7     HONDA
# 8    TOYOTA
# 9    NISSAN
# Name: Make, dtype: object

# %%
cs["Price"] = cs["Price"].str.replace('[$\,\.]','').astype(int)
# Out:
# C:\Users\AMIT JANI\AppData\Local\Temp\ipykernel_5964\3183201740.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   cs["Price"] = cs["Price"].str.replace('[$\,\.]','').astype(int)

# %%
cs["Make"]=cs["Make"].str.upper()

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
cms = pd.read_csv("car-sales-missing-data.csv")

# %%
cms
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
cms["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
cms["Odometer"].fillna(cms["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
cms
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
cms["Colour"]=cms["Colour"].fillna("Red")

# %%
cms
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    Red   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
cms
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    Red       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
cms["Doors"].fillna(10.0,inplace=True)

# %%
cms
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    Red       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0   10.0      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Remove all rows wit NULL values from the DataFrame.
cms["Price"].dropna()
# Out:
# 0     $4,000
# 1     $5,000
# 2     $7,000
# 3    $22,000
# 4     $3,500
# 5     $4,500
# 6     $7,500
# 9     $9,700
# Name: Price, dtype: object

# %%
cms
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    Red       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0   10.0      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
cms = cms.dropna()

# %%
cms
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    Red   92302.666667    4.0   $7,500

# %%
s1 = pd.Series([2,3,4,5,6])
s2 = pd.Series([11,22,33,44,55])
d = pd.DataFrame({"set1":s1,"set2":s2})

# %%
d
# Out:
#    set1  set2
# 0     2    11
# 1     3    22
# 2     4    33
# 3     5    44
# 4     6    55

# %%
cms
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    Red   92302.666667    4.0   $7,500

# %%
name = pd.Series(["sagar","harsh","vrutik","heet","chirag","femish"])

# %%
cs = pd.read_csv("car-sales.csv")

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
cs = cs.dropna()

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
crs = cs.sample(frac=1)

# %%
crs
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price
# 2      2  Toyota   Blue          32549      3   $7,000.00
# 1      1   Honda    Red          87899      4   $5,000.00
# 7      7   Honda   Blue          54738      4   $7,000.00
# 5      5  Toyota  Green          99213      4   $4,500.00
# 3      3     BMW  Black          11179      5  $22,000.00
# 9      9  Nissan  White          31600      4   $9,700.00
# 6      6   Honda   Blue          45698      4   $7,500.00
# 4      4  Nissan  White         213095      4   $3,500.00
# 8      8  Toyota  White          60000      4   $6,250.00
# 0      0  Toyota  White         150043      4   $4,000.00

# %%
crs.reset_index()
# Out:
#    level_0  index    Make Colour  Odometer (KM)  Doors       Price
# 0        2      2  Toyota   Blue          32549      3   $7,000.00
# 1        1      1   Honda    Red          87899      4   $5,000.00
# 2        7      7   Honda   Blue          54738      4   $7,000.00
# 3        5      5  Toyota  Green          99213      4   $4,500.00
# 4        3      3     BMW  Black          11179      5  $22,000.00
# 5        9      9  Nissan  White          31600      4   $9,700.00
# 6        6      6   Honda   Blue          45698      4   $7,500.00
# 7        4      4  Nissan  White         213095      4   $3,500.00
# 8        8      8  Toyota  White          60000      4   $6,250.00
# 9        0      0  Toyota  White         150043      4   $4,000.00

# %%
crs.reset_index(drop = True,inplace = True)

# %%
crs
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price
# 0      2  Toyota   Blue          32549      3   $7,000.00
# 1      1   Honda    Red          87899      4   $5,000.00
# 2      7   Honda   Blue          54738      4   $7,000.00
# 3      5  Toyota  Green          99213      4   $4,500.00
# 4      3     BMW  Black          11179      5  $22,000.00
# 5      9  Nissan  White          31600      4   $9,700.00
# 6      6   Honda   Blue          45698      4   $7,500.00
# 7      4  Nissan  White         213095      4   $3,500.00
# 8      8  Toyota  White          60000      4   $6,250.00
# 9      0  Toyota  White         150043      4   $4,000.00

# %%
cs
# Out:
#    index    Make Colour  Odometer (KM)  Doors       Price
# 0      0  Toyota  White         150043      4   $4,000.00
# 1      1   Honda    Red          87899      4   $5,000.00
# 2      2  Toyota   Blue          32549      3   $7,000.00
# 3      3     BMW  Black          11179      5  $22,000.00
# 4      4  Nissan  White         213095      4   $3,500.00
# 5      5  Toyota  Green          99213      4   $4,500.00
# 6      6   Honda   Blue          45698      4   $7,500.00
# 7      7   Honda   Blue          54738      4   $7,000.00
# 8      8  Toyota  White          60000      4   $6,250.00
# 9      9  Nissan  White          31600      4   $9,700.00

# %%
cs = pd.read_csv("car-sales.csv")

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
cs["Odometer (KM)"] = cs["Odometer (KM)"].apply(lambda x:x/100)

# %%
cs
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White        1500.43      4   $4,000.00
# 1   Honda    Red         878.99      4   $5,000.00
# 2  Toyota   Blue         325.49      3   $7,000.00
# 3     BMW  Black         111.79      5  $22,000.00
# 4  Nissan  White        2130.95      4   $3,500.00
# 5  Toyota  Green         992.13      4   $4,500.00
# 6   Honda   Blue         456.98      4   $7,500.00
# 7   Honda   Blue         547.38      4   $7,000.00
# 8  Toyota  White         600.00      4   $6,250.00
# 9  Nissan  White         316.00      4   $9,700.00
